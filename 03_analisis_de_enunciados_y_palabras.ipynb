# %% [markdown]
# # Análisis de enunciados y palabras en español

# %% [markdown]
# ## Ejercicio a entregarEl objetivo de este ejercicio es construir, paso a paso, herramientas para analizarun texto en español: separarlo en enunciados, separar los enunciados en palabras,y analizar cada palabra en términos de sílabas, letras y fonemas.Se puede asumir que el texto de entrada es un texto formal en español que respetalas reglas de puntuación y ortografía (por ejemplo, un fragmento de una noticia,un ensayo o un texto académico).

# %% [markdown]
# ## 1. De texto a enunciadosCrea una función que reciba un texto largo (uno o varios párrafos) y regrese unalista con los enunciados que lo componen.Pista: en un texto formal en español, los enunciados terminan en un signo depuntuación como `.`, `?`, `!` o `...`

# %%
def texto_a_enunciados(texto):    """    Recibe un texto (uno o varios párrafos) en español formal y regresa    una lista con los enunciados (str) que lo componen.    """    # Tu código aquí    pass

# %% [markdown]
# ## 2. De enunciado a palabrasCrea una función que reciba un enunciado y regrese una lista con las palabrasque lo componen (sin signos de puntuación).

# %%
def enunciado_a_palabras(enunciado):    """    Recibe un enunciado (str) y regresa una lista con las palabras del enunciado.    """    # Tu código aquí    pass

# %% [markdown]
# ## 3. Clase `Enunciado`Un objeto `Enunciado` se construye a partir de un enunciado (str) y guarda suspalabras en un orden fijo (el orden en el que aparecen en el texto).Métodos que debe tener:- `palabras_totales()`: regresa el número total de palabras del enunciado.- `palabras()`: regresa una lista con las palabras del enunciado, en orden.- `palabras_unicas()`: regresa un conjunto con las palabras únicas del enunciado.

# %%
class Enunciado:    def __init__(self, enunciado):        self.enunciado = enunciado        self.lista_palabras = enunciado_a_palabras(enunciado)    def palabras_totales(self):        # Tu código aquí        pass    def palabras(self):        # Tu código aquí        pass    def palabras_unicas(self):        # Tu código aquí        pass

# %% [markdown]
# ## 4. Clase `Palabra`Un objeto `Palabra` se construye a partir de una palabra (str) en español.Debe tener los siguientes atributos/métodos:- `silaba_tonica`: si la palabra es aguda, grave o esdrújula.- `silabas`: una lista con las sílabas de la palabra.- `numero_de_letras`: cuántas letras tiene la palabra.- `conjunto_de_letras`: las letras de la palabra sin repeticiones.- `vocales`: las vocales de la palabra.- `consonantes`: las consonantes de la palabra.- `fonemas`: los fonemas de la palabra. Algunos dígrafos (por ejemplo `ch`, `ll`,  `rr`, `qu`, `gu`) se cuentan como un solo fonema.

# %%
class Palabra:    def __init__(self, palabra):        self.palabra = palabra    @property    def silabas(self):        # Tu código aquí        pass    @property    def silaba_tonica(self):        # Debe regresar "aguda", "grave" o "esdrújula"        pass    @property    def numero_de_letras(self):        # Tu código aquí        pass    @property    def conjunto_de_letras(self):        # Tu código aquí        pass    @property    def vocales(self):        # Tu código aquí        pass    @property    def consonantes(self):        # Tu código aquí        pass    @property    def fonemas(self):        # Tu código aquí        pass

# %% [markdown]
# ## 5. Palabras en otra lenguaCrea una clase que analice palabras, pero en otra lengua (por ejemplo, inglés,francés, náhuatl, etc.).Después de construirla, responde en la siguiente celda:- ¿Se pueden reutilizar las mismas funciones/métodos que la clase `Palabra` que  analiza palabras en español?- ¿Qué habría que cambiar?- ¿Qué se puede conservar?

# %%
class PalabraOtraLengua:    def __init__(self, palabra):        self.palabra = palabra    # Define aquí los métodos/atributos que sí se puedan reutilizar    # y los que haya que cambiar respecto a la clase Palabra en español.

# %% [markdown]
# ### Respuesta_Escribe aquí tu respuesta a las preguntas de reutilización de la sección anterior._
