# %%
## Estructura de datos

### Listas, se definen entre corchetes

letras = ["a", "b", "c", "d","e"]

palabras_y_numeros = ["a", "b", "c", 2, 3, 4 ]

lista_vacia = list()

### Son mutables

### Tuplas se definen entre paréntesis

tupla = (1, 2, 3)

tupla_vacia = tuple()
### No son mutables

### Conjuntos, se definen entre llaves, desordenados

conjunto = {"a", "b", "c"}

conjunto_vacio = set()

## Diccionarios, se definen con llaves

diccionario = {
    "clave": "valor" # key-value
}


diccionario_vacio = dict()

# Desde Python 3.7, los diccionarios son ordenados.
# En versiones anteriores, son desordenados

# %%
## Ejemplo de diccionario
perfil_1 = {
    "edad": 34,
    "peso": 58,
    "intereses": ["fucho", "bicla", "patines"],
    "direcciones": {
        "Mexico": "Magdalena 135",
        "Suecia": "Gotemburgo 123"
    }
}

perfil_2 = {
    "edad": 36,
    "peso": 58
}

# %%
## Ejemplo de recuperar valores con claves
print(perfil_1["direcciones"]["Mexico"])
# Out:
# Magdalena 135

# %% [markdown]
# ## Ejercicio
#
# Escoger un párrafo, definirlo en una variable y responder:
#
# 1. ¿Cuántas palabras tiene el párrafo'
# 2. ¿Cuántas preposiciones tiene el párrafo? (total, con repetidas)
# 3. ¿Cuántas preposiciones tiene el párrafo (sin repeticiones)
# 4. En un diccionario, guarda los resultados
