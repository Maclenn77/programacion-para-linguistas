# %%
texto = "Escuela Nacional de Antropologia e Historia"
print(texto.upper())
print(texto.lower())
print(texto[:3])
print(texto[-3:])
vocales = [letra for letra in texto if letra.lower() in "aeiou"]
print(vocales)
lista_palabras = texto.split()
print(lista_palabras)
# Out:
# ESCUELA NACIONAL DE ANTROPOLOGIA E HISTORIA
# escuela nacional de antropologia e historia
# Esc
# ria
# ['E', 'u', 'e', 'a', 'a', 'i', 'o', 'a', 'e', 'A', 'o', 'o', 'o', 'i', 'a', 'e', 'i', 'o', 'i', 'a']
# ['Escuela', 'Nacional', 'de', 'Antropologia', 'e', 'Historia']
